# %% [markdown]
# ### Create Virtual Environment

# %% [markdown]
# ##### Open Folder of your project

# %%
python -m venv env_name

# %% [markdown]
# ### Activate the Environment

# %%
env_name\Scripts\activate

deactivate # deactivate

# %% [markdown]
# ### Delete Virtual Environment

# %%
rmdir /s /q env_name
