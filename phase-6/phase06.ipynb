# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
d = {
    'Custome' : ['Riya', 'Aman', 'Faizan', 'Neha', 'Imran', 'Sneha'],
    'Age' : [20,30,40,22,38,25],
    'Spending' : [100,200,300,110,190,130]
}

data = pd.DataFrame(d)
X = data[['Age', 'Spending']]

# %%
model = KMeans(n_clusters=2, random_state=42, n_init=10)

# %%
data['Group'] = model.fit_predict(X)

# %%
plt.figure(figsize=(6,5))
for group in data['Group'].unique():
    group_data = data[data['Group'] == group]
    plt.scatter(group_data['Age'], group_data['Spending'], label=f'Group {group}')

plt.xlabel('Age')
plt.ylabel('Spending score')
plt.grid()
plt.show()

# %%
print(data)
# Out:
#   Custome  Age  Spending  Group
# 0    Riya   20       100      0
# 1    Aman   30       200      1
# 2  Faizan   40       300      1
# 3    Neha   22       110      0
# 4   Imran   38       190      1
# 5   Sneha   25       130      0

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
d = {
    'Age' : [25,30,35,40,45,50],
    'Income' : [30000, 40000, 50000, 60000, 70000, 80000],
    'Spending' : [70, 60, 50, 40, 30, 20],
    'Saving' : [1000, 5000, 8000, 10000, 15000, 20000]
}
data = pd.DataFrame(d)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

pca_df = pd.DataFrame(pca_result)

explained_variance = pca.explained_variance_ratio_
print("Variance captured by each PCA component : ")
print(np.round(explained_variance * 100, 2))
# Out:
# Variance captured by each PCA component :
# [99.65  0.35]

# %%
print(pca_df)
# Out:
#           0         1
# 0 -2.901838  0.038962
# 1 -1.703939  0.088054
# 2 -0.585677 -0.001447
# 3  0.452949 -0.229542
# 4  1.730485 -0.041856
# 5  3.008020  0.145829

# %%
plt.figure(figsize=(8,6))
plt.scatter(pca_df[0], pca_df[1], color='blue')
plt.title("PCA Projection ( 2D View )")
plt.xlabel('PCA1 Main Pattern')
plt.ylabel('PCA2 Minor Pattern')
plt.grid(True)
plt.show()
print("New data with 2 features pca1 & pca 2")
print(pca_df)
# Out:
# New data with 2 features pca1 & pca 2
#           0         1
# 0 -2.901838  0.038962
# 1 -1.703939  0.088054
# 2 -0.585677 -0.001447
# 3  0.452949 -0.229542
# 4  1.730485 -0.041856
# 5  3.008020  0.145829
